# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (8.3.175)
# Requirement already satisfied: opencv-python in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (3.10.5)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\harsh\appdata\roaming\python\python310\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from ultralytics) (2.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\harsh\appdata\roaming\python\python310\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsh\anaconda3\envs\yolov_env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
from ultralytics import YOLO
import cv2 as cv

# Load trained model
model = YOLO(r"best.pt")

# Open webcam
cap = cv.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run inference
    results = model(frame, conf=0.3, verbose=False)

    # Process results
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = float(box.conf[0])
            cls_id = int(box.cls[0])
            label = f"{model.names[cls_id]} {conf:.2f}"

            # Draw bounding box & label
            cv.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv.putText(frame, label, (x1, y1 - 10),
                       cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Show frame
    cv.imshow("Helmet Detection", frame)

    # Exit if 'q' is pressed
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv.destroyAllWindows()

# %%
from ultralytics import YOLO
import cv2 as cv

# Load trained model
model = YOLO(r"best.pt")

# Open webcam
cap = cv.VideoCapture(r"manwearing.mp4")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run inference
    results = model(frame, conf=0.3, verbose=False)

    # Process results
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = float(box.conf[0])
            cls_id = int(box.cls[0])
            label = f"{model.names[cls_id]} {conf:.2f}"

            # Draw bounding box & label
            cv.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv.putText(frame, label, (x1, y1 - 10),
                       cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Show frame
    cv.imshow("Helmet Detection", frame)

    # Exit if 'q' is pressed
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
